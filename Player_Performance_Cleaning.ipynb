# %% [markdown]
# Hier entsteht das Projekt bla bla bla

# %%
import pandas as pd
import numpy as np
import re

# %%
player_stats = pd.read_csv('2021-2022_Football_Player_Stats.csv', encoding='latin1', sep=';')
fifa_data = pd.read_csv('FIFA23_official_data.csv', encoding='latin1')

columns_to_remove_fifa = ['Photo', 'Club Logo', 'Flag', 'Real Face', 'Best Overall Rating', 
                         'Joined', 'Loaned From', 'Contract Valid Until', 'Release Clause', 'Kit Number']
fifa_data = fifa_data.drop(columns=[col for col in columns_to_remove_fifa if col in fifa_data.columns])

player_stats = player_stats[player_stats['Min'] >= 100]
player_stats = player_stats[player_stats['MP'] >= 5]

def extract_last_name_from_full(full_name):
    if pd.isna(full_name):
        return ""
    parts = str(full_name).strip().split()
    return parts[-1].lower() if parts else ""

def extract_names_from_fifa(fifa_name):
    if pd.isna(fifa_name):
        return "", ""
    
    name_str = str(fifa_name).strip()
    name_str = re.sub(r'[^a-zA-Z\s\.]', '', name_str)
    parts = name_str.split()
    
    if len(parts) >= 2:
        first_name_abbr = parts[0].replace('.', '').lower()
        last_name = parts[-1].lower()
        return first_name_abbr, last_name
    elif len(parts) == 1:
        return "", parts[0].lower()
    else:
        return "", ""

player_stats['last_name_temp'] = player_stats['Player'].apply(extract_last_name_from_full)
fifa_data['last_name_temp'] = fifa_data['Name'].apply(lambda x: extract_names_from_fifa(x)[1])

common_last_names = set(player_stats['last_name_temp']).intersection(set(fifa_data['last_name_temp']))

def find_best_matches():
    matches = []
    
    for last_name in common_last_names:
        stats_players = player_stats[player_stats['last_name_temp'] == last_name]
        fifa_players = fifa_data[fifa_data['last_name_temp'] == last_name]
        
        for _, stats_row in stats_players.iterrows():
            stats_full_name = stats_row['Player']
            stats_first_initial = stats_full_name[0].lower() if stats_full_name else ""
            
            for _, fifa_row in fifa_players.iterrows():
                fifa_full_name = fifa_row['Name']
                fifa_first_abbr = extract_names_from_fifa(fifa_full_name)[0]
                
                if (stats_first_initial == fifa_first_abbr or 
                    len(stats_players) == 1 or 
                    len(fifa_players) == 1):
                    
                    matches.append({
                        'stats_name': stats_full_name,
                        'fifa_name': fifa_full_name,
                        'last_name': last_name,
                        'stats_index': stats_row.name,
                        'fifa_index': fifa_row.name,
                        'confidence': 'high' if stats_first_initial == fifa_first_abbr else 'medium'
                    })
    
    return matches

best_matches = find_best_matches()

if len(best_matches) > 0:
    stats_indices = [match['stats_index'] for match in best_matches]
    fifa_indices = [match['fifa_index'] for match in best_matches]
    
    player_stats_filtered = player_stats.loc[stats_indices].drop('last_name_temp', axis=1)
    fifa_data_filtered = fifa_data.loc[fifa_indices].drop('last_name_temp', axis=1)

    for i in range(min(3, len(player_stats_filtered))):
        player_name = player_stats_filtered['Player'].iloc[i]
        goals = player_stats_filtered['Goals'].iloc[i] if 'Goals' in player_stats_filtered.columns else 'N/A'
        assists = player_stats_filtered['Assists'].iloc[i] if 'Assists' in player_stats_filtered.columns else 'N/A'
        minutes = player_stats_filtered['Min'].iloc[i] if 'Min' in player_stats_filtered.columns else 'N/A'
        
        fifa_match = fifa_data_filtered[fifa_data_filtered['Name'].str.contains(player_name.split()[-1], na=False)]
        fifa_overall = fifa_match['Overall'].iloc[0] if len(fifa_match) > 0 else 'N/A'
    
    player_stats_filtered.to_csv('player_stats_complete_filtered.csv', index=False)
    fifa_data_filtered.to_csv('fifa_data_complete_filtered.csv', index=False)
    
    mapping_df = pd.DataFrame(best_matches)
    
    combined_data = player_stats_filtered.copy()

# %%
player_stats_filtered = pd.read_csv('player_stats_complete_filtered.csv')
fifa_data_filtered = pd.read_csv('fifa_data_complete_filtered.csv')

fifa_duplicates = fifa_data_filtered[fifa_data_filtered.duplicated(subset=['Name'], keep=False)]

if len(fifa_duplicates) > 0:
    fifa_data_clean = fifa_data_filtered.sort_values('Overall', ascending=False).drop_duplicates(subset=['Name'], keep='first')
else:
    fifa_data_clean = fifa_data_filtered.copy()

player_stats_filtered = player_stats_filtered.copy()
player_stats_filtered['unique_key'] = player_stats_filtered.apply(
    lambda x: f"{x['Player']}_{x['Born']}_{x['Nation']}", 
    axis=1
)

transfer_players = player_stats_filtered[player_stats_filtered.duplicated(subset=['unique_key'], keep=False)]

if len(transfer_players) > 0:    
    for player_key in transfer_players['unique_key'].unique():
        player_entries = transfer_players[transfer_players['unique_key'] == player_key]
    
    player_stats_clean = player_stats_filtered.drop_duplicates(subset=['unique_key'], keep=False)
    player_stats_clean = player_stats_clean.drop('unique_key', axis=1)
else:
    player_stats_clean = player_stats_filtered.drop('unique_key', axis=1)

def get_last_name(name):
    return str(name).split()[-1].lower() if pd.notna(name) else ""

player_stats_clean['last_name_temp'] = player_stats_clean['Player'].apply(get_last_name)
fifa_data_clean['last_name_temp'] = fifa_data_clean['Name'].apply(get_last_name)

common_players_after_clean = set(player_stats_clean['last_name_temp']).intersection(
    set(fifa_data_clean['last_name_temp'])
)

player_stats_final = player_stats_clean[
    player_stats_clean['last_name_temp'].isin(common_players_after_clean)
].drop('last_name_temp', axis=1)

fifa_data_final = fifa_data_clean[
    fifa_data_clean['last_name_temp'].isin(common_players_after_clean)
].drop('last_name_temp', axis=1)

player_stats_final.to_csv('player_stats_cleaned_separate.csv', index=False)

fifa_data_final.to_csv('fifa_data_cleaned_separate.csv', index=False)

mapping_data = []

for stats_idx, stats_row in player_stats_final.iterrows():
    stats_name = stats_row['Player']
    stats_last_name = get_last_name(stats_name)
    
    matching_fifa = fifa_data_final[
        fifa_data_final['Name'].apply(get_last_name) == stats_last_name
    ]
    
    if len(matching_fifa) > 0:
        fifa_name = matching_fifa['Name'].iloc[0]
        fifa_overall = matching_fifa['Overall'].iloc[0]
        
        mapping_data.append({
            'Stats_Player': stats_name,
            'FIFA_Player': fifa_name,
            'Last_Name': stats_last_name,
            'FIFA_Overall': fifa_overall,
            'Stats_Squad': stats_row['Squad'] if 'Squad' in stats_row else 'N/A',
            'FIFA_Club': matching_fifa['Club'].iloc[0] if 'Club' in matching_fifa.columns else 'N/A'
        })

mapping_df = pd.DataFrame(mapping_data)
mapping_df.to_csv('player_mapping_separate.csv', index=False)
# Out:
# 🔄 Entferne 422 Spieler mit Transfers:
#    ❌ Joselu_1990_ESP - Vereine: ['Alavï¿½s', 'Alavï¿½s']
#    ❌ Sï¿½rgio Oliveira_1992_POR - Vereine: ['Roma', 'Roma', 'Roma', 'Roma', 'Roma', 'Roma', 'Roma', 'Roma']
#    ❌ Andrea Schiavone_1993_ITA - Vereine: ['Salernitana', 'Salernitana']
#    ❌ Fernando_1987_BRA - Vereine: ['Sevilla', 'Sevilla', 'Sevilla', 'Sevilla']
#    ❌ Christoph Kramer_1991_GER - Vereine: ["M'Gladbach", "M'Gladbach"]
#    ❌ Wataru Endo_1993_JPN - Vereine: ['Stuttgart', 'Stuttgart']
#    ❌ Rï¿½ben Dias_1997_POR - Vereine: ['Manchester City', 'Manchester City', 'Manchester City', 'Manchester City']
#    ❌ Jonas Hofmann_1992_GER - Vereine: ["M'Gladbach", "M'Gladbach", "M'Gladbach"]
#    ❌ Nahuel Molina_1997_ARG - Vereine: ['Udinese', 'Udinese']
#    ❌ Kevin Vogt_1991_GER - Vereine: ['Hoffenheim', 'Hoffenheim']
#    ❌ Son_1994_ESP - Vereine: ['Levante', 'Levante']
#    ❌ Timothy Weah_2000_USA - Vereine: ['Lille', 'Lille']
#    ❌ Tolgay Arslan_1990_GER - Vereine: ['Udinese', 'Udinese', 'Udinese']
#    ❌ Claudio Bravo_1983_CHI - Vereine: ['Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis']
#    ❌ Anthony Gordon_2001_ENG - Vereine: ['Everton', 'Everton', 'Everton', 'Everton', 'Everton', 'Everton', 'Everton', 'Everton', 'Everton']
#    ❌ Marcus Thuram_1997_FRA - Vereine: ["M'Gladbach", "M'Gladbach"]
#    ❌ Cristhian Mosquera_2004_COL - Vereine: ['Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia']
#    ❌ M'Baye Niang_1994_SEN - Vereine: ['Bordeaux', 'Bordeaux']
#    ❌ Stï¿½phane Diarra_1998_FRA - Vereine: ['Lorient', 'Lorient', 'Lorient', 'Lorient', 'Lorient', 'Lorient']
#    ❌ Deyovaisio Zeefuik_1998_NED - Vereine: ['Hertha BSC', 'Hertha BSC']
#    ❌ Sean Longstaff_1997_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ Jeison Murillo_1992_COL - Vereine: ['Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo']
#    ❌ Amadou Onana_2001_BEL - Vereine: ['Lille', 'Lille']
#    ❌ Kevin Danso_1998_AUT - Vereine: ['Lens', 'Lens']
#    ❌ Konrad De La Fuente_2001_USA - Vereine: ['Marseille', 'Marseille']
#    ❌ Jordan Ayew_1991_GHA - Vereine: ['Crystal Palace', 'Crystal Palace']
#    ❌ Mohamed Bayo_1998_GUI - Vereine: ['Clermont Foot', 'Clermont Foot']
#    ❌ Bradley Barcola_2002_FRA - Vereine: ['Lyon', 'Lyon']
#    ❌ Kaio Jorge_2002_BRA - Vereine: ['Juventus', 'Juventus']
#    ❌ Maxence Lacroix_2000_FRA - Vereine: ['Wolfsburg', 'Wolfsburg']
#    ❌ Danilo_1991_BRA - Vereine: ['Juventus', 'Juventus', 'Juventus', 'Juventus']
#    ❌ Timothy Chandler_1990_USA - Vereine: ['Eint Frankfurt', 'Eint Frankfurt', 'Eint Frankfurt']
#    ❌ Joshua King_1992_NOR - Vereine: ['Watford', 'Watford', 'Watford', 'Watford', 'Watford']
#    ❌ Tammy Abraham_1997_ENG - Vereine: ['Roma', 'Roma', 'Roma', 'Roma', 'Roma']
#    ❌ Alessandro Florenzi_1991_ITA - Vereine: ['Milan', 'Milan']
#    ❌ ï¿½dï¿½m Szalai_1987_HUN - Vereine: ['Mainz 05', 'Mainz 05']
#    ❌ Danny Blum_1991_GER - Vereine: ['Bochum', 'Bochum', 'Bochum']
#    ❌ Yan Valery_1999_FRA - Vereine: ['Southampton', 'Southampton']
#    ❌ Kyle Walker_1990_ENG - Vereine: ['Manchester City', 'Manchester City', 'Manchester City', 'Manchester City', 'Manchester City', 'Manchester City', 'Manchester City']
#    ❌ Wout Weghorst_1992_NED - Vereine: ['Burnley', 'Wolfsburg']
#    ❌ Maxime Lopez_1997_FRA - Vereine: ['Sassuolo', 'Sassuolo']
#    ❌ Michael Keane_1993_ENG - Vereine: ['Everton', 'Everton']
#    ❌ Daniele Baselli_1992_ITA - Vereine: ['Torino', 'Cagliari']
#    ❌ Robin Gosens_1994_GER - Vereine: ['Atalanta', 'Inter']
#    ❌ Raphaï¿½l Varane_1993_FRA - Vereine: ['Manchester Utd', 'Manchester Utd']
#    ❌ Juan Bernat_1993_ESP - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Josh Sargent_2000_USA - Vereine: ['Norwich City', 'Norwich City']
#    ❌ Alfred Duncan_1993_GHA - Vereine: ['Fiorentina', 'Fiorentina']
#    ❌ Aaron Lennon_1987_ENG - Vereine: ['Burnley', 'Burnley']
#    ❌ Frenkie de Jong_1997_NED - Vereine: ['Barcelona', 'Barcelona']
#    ❌ Musa Barrow_1998_GAM - Vereine: ['Bologna', 'Bologna']
#    ❌ Seko Fofana_1995_CIV - Vereine: ['Lens', 'Lens']
#    ❌ Youssouf Fofana_1999_FRA - Vereine: ['Monaco', 'Monaco']
#    ❌ Roberto Pereyra_1991_ARG - Vereine: ['Udinese', 'Udinese']
#    ❌ Federico Di Francesco_1994_ITA - Vereine: ['Empoli', 'Empoli']
#    ❌ Nico Elvedi_1996_SUI - Vereine: ["M'Gladbach", "M'Gladbach"]
#    ❌ Mouctar Diakhaby_1996_FRA - Vereine: ['Valencia', 'Valencia']
#    ❌ Mathï¿½as Olivera_1997_URU - Vereine: ['Getafe', 'Getafe', 'Getafe', 'Getafe', 'Getafe']
#    ❌ Josuha Guilavogui_1990_FRA - Vereine: ['Bordeaux', 'Wolfsburg']
#    ❌ Marc Roca_1996_ESP - Vereine: ['Bayern Munich', 'Bayern Munich', 'Bayern Munich', 'Bayern Munich', 'Bayern Munich', 'Bayern Munich']
#    ❌ Alfred Gomis_1993_SEN - Vereine: ['Rennes', 'Rennes', 'Rennes']
#    ❌ Andrew Robertson_1994_SCO - Vereine: ['Liverpool', 'Liverpool', 'Liverpool', 'Liverpool']
#    ❌ Romelu Lukaku_1993_BEL - Vereine: ['Chelsea', 'Chelsea']
#    ❌ Granit Xhaka_1992_SUI - Vereine: ['Arsenal', 'Arsenal', 'Arsenal']
#    ❌ Billy Gilmour_2001_SCO - Vereine: ['Norwich City', 'Norwich City', 'Norwich City']
#    ❌ Gideon Jung_1994_GER - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Leander Dendoncker_1995_BEL - Vereine: ['Wolves', 'Wolves']
#    ❌ Nico Schulz_1993_GER - Vereine: ['Dortmund', 'Dortmund', 'Dortmund', 'Dortmund', 'Dortmund', 'Dortmund']
#    ❌ Yeremi Pino_2002_ESP - Vereine: ['Villarreal', 'Villarreal', 'Villarreal']
#    ❌ Adam Webster_1995_ENG - Vereine: ['Brighton', 'Brighton', 'Brighton']
#    ❌ William Saliba_2001_FRA - Vereine: ['Marseille', 'Marseille']
#    ❌ Giovani Lo Celso_1996_ARG - Vereine: ['Tottenham', 'Villarreal']
#    ❌ Thierry Correia_1999_POR - Vereine: ['Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia', 'Valencia']
#    ❌ Ferrï¿½n Torres_2000_ESP - Vereine: ['Barcelona', 'Barcelona', 'Barcelona', 'Barcelona']
#    ❌ Gianluigi Donnarumma_1999_ITA - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Samuele Ricci_2001_ITA - Vereine: ['Empoli', 'Torino']
#    ❌ Romain Del Castillo_1996_FRA - Vereine: ['Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest', 'Brest']
#    ❌ Rodri_1996_ESP - Vereine: ['Manchester City', 'Manchester City', 'Manchester City']
#    ❌ Andreas Skov Olsen_1999_DEN - Vereine: ['Bologna', 'Bologna']
#    ❌ Philippe Coutinho_1992_BRA - Vereine: ['Aston Villa', 'Barcelona']
#    ❌ Stefan Bajic_2001_FRA - Vereine: ['Saint-ï¿½tienne', 'Saint-ï¿½tienne']
#    ❌ Dante_1983_BRA - Vereine: ['Nice', 'Nice']
#    ❌ Jannik Vestergaard_1992_DEN - Vereine: ['Leicester City', 'Leicester City']
#    ❌ Takumi Minamino_1995_JPN - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Maximilian Philipp_1994_GER - Vereine: ['Wolfsburg', 'Wolfsburg', 'Wolfsburg']
#    ❌ Fabio Depaoli_1997_ITA - Vereine: ['Sampdoria', 'Hellas Verona']
#    ❌ Alex McCarthy_1989_ENG - Vereine: ['Southampton', 'Southampton']
#    ❌ Leandro Cabrera_1991_URU - Vereine: ['Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol']
#    ❌ Lorenzo Pellegrini_1996_ITA - Vereine: ['Roma', 'Roma']
#    ❌ Luca Pellegrini_1999_ITA - Vereine: ['Juventus', 'Juventus']
#    ❌ Jonjoe Kenny_1997_ENG - Vereine: ['Everton', 'Everton', 'Everton']
#    ❌ Ruben Aguilar_1993_FRA - Vereine: ['Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco', 'Monaco']
#    ❌ Mauro Arambarri_1995_URU - Vereine: ['Getafe', 'Getafe']
#    ❌ Dan Burn_1992_ENG - Vereine: ['Brighton', 'Newcastle Utd']
#    ❌ Emil Forsberg_1991_SWE - Vereine: ['RB Leipzig', 'RB Leipzig']
#    ❌ Ibrahima Sissoko_1997_FRA - Vereine: ['Strasbourg', 'Strasbourg']
#    ❌ Sambou Sissoko_1999_FRA - Vereine: ['Reims', 'Reims']
#    ❌ Robin Le Normand_1996_FRA - Vereine: ['Real Sociedad', 'Real Sociedad']
#    ❌ Abdourahmane Barry_2000_FRA - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Felipe Caicedo_1988_ECU - Vereine: ['Genoa', 'Genoa']
#    ❌ Moisï¿½s Caicedo_2001_ECU - Vereine: ['Brighton', 'Brighton']
#    ❌ ï¿½lex Collado_1999_ESP - Vereine: ['Granada', 'Granada']
#    ❌ Christian Eriksen_1992_DEN - Vereine: ['Brentford', 'Brentford', 'Brentford']
#    ❌ Lassana Coulibaly_1996_MLI - Vereine: ['Salernitana', 'Salernitana']
#    ❌ Darï¿½o Benedetto_1990_ARG - Vereine: ['Elche', 'Elche']
#    ❌ Joe Gomez_1997_ENG - Vereine: ['Liverpool', 'Liverpool', 'Liverpool', 'Liverpool']
#    ❌ R?zvan Marin_1996_ROU - Vereine: ['Cagliari', 'Cagliari', 'Cagliari']
#    ❌ Francisco Garcia_1999_ESP - Vereine: ['Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano']
#    ❌ Jack Harrison_1996_ENG - Vereine: ['Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Felipe Anderson_1993_BRA - Vereine: ['Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio', 'Lazio']
#    ❌ Hianga Mananga Mbock_1999_FRA - Vereine: ['Brest', 'Brest']
#    ❌ Nicolas Jackson_2001_SEN - Vereine: ['Villarreal', 'Villarreal', 'Villarreal', 'Villarreal', 'Villarreal', 'Villarreal', 'Villarreal']
#    ❌ Trevoh Chalobah_1999_ENG - Vereine: ['Chelsea', 'Chelsea']
#    ❌ Luis Alberto_1992_ESP - Vereine: ['Lazio', 'Lazio', 'Lazio']
#    ❌ Christian Pulisic_1998_USA - Vereine: ['Chelsea', 'Chelsea']
#    ❌ Marc-Oliver Kempf_1995_GER - Vereine: ['Hertha BSC', 'Stuttgart']
#    ❌ Stefano Sensi_1995_ITA - Vereine: ['Inter', 'Sampdoria']
#    ❌ Antonio Sanabria_1996_PAR - Vereine: ['Torino', 'Torino', 'Torino', 'Torino']
#    ❌ Patrick Wimmer_2001_AUT - Vereine: ['Arminia', 'Arminia']
#    ❌ Eddie Salcedo_2001_ITA - Vereine: ['Spezia', 'Spezia']
#    ❌ Ben Foster_1983_ENG - Vereine: ['Watford', 'Watford', 'Watford', 'Watford']
#    ❌ Emre Can_1994_GER - Vereine: ['Dortmund', 'Dortmund']
#    ❌ Augusto Solari_1992_ARG - Vereine: ['Celta Vigo', 'Celta Vigo']
#    ❌ Timo Werner_1996_GER - Vereine: ['Chelsea', 'Chelsea']
#    ❌ Germï¿½n Pezzella_1991_ARG - Vereine: ['Betis', 'Betis']
#    ❌ Giuseppe Pezzella_1997_ITA - Vereine: ['Atalanta', 'Atalanta']
#    ❌ Kelvin Yeboah_2000_ITA - Vereine: ['Genoa', 'Genoa', 'Genoa']
#    ❌ Joel Ward_1989_ENG - Vereine: ['Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace']
#    ❌ Roberto Piccoli_2001_ITA - Vereine: ['Genoa', 'Atalanta']
#    ❌ Toni Moya_1998_ESP - Vereine: ['Alavï¿½s', 'Alavï¿½s']
#    ❌ Guido Carrillo_1991_ARG - Vereine: ['Elche', 'Elche', 'Elche', 'Elche']
#    ❌ Joe Willock_1999_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ David Soria_1993_ESP - Vereine: ['Getafe', 'Getafe', 'Getafe', 'Getafe']
#    ❌ Vanderson_2001_BRA - Vereine: ['Monaco', 'Monaco']
#    ❌ Mamadou Sylla_1994_SEN - Vereine: ['Alavï¿½s', 'Rayo Vallecano']
#    ❌ Solly March_1994_ENG - Vereine: ['Brighton', 'Brighton']
#    ❌ Raï¿½l Guti_1996_ESP - Vereine: ['Elche', 'Elche', 'Elche']
#    ❌ Junior Firpo_1996_ESP - Vereine: ['Leeds United', 'Leeds United']
#    ❌ Max Kruse_1988_GER - Vereine: ['Wolfsburg', 'Union Berlin']
#    ❌ Ansgar Knauff_2002_GER - Vereine: ['Eint Frankfurt', 'Dortmund']
#    ❌ Nicolï¿½s Serrano_2003_ESP - Vereine: ['Athletic Club', 'Athletic Club', 'Athletic Club', 'Athletic Club', 'Athletic Club', 'Athletic Club']
#    ❌ Ben Johnson_2000_ENG - Vereine: ['West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham', 'West Ham']
#    ❌ Jonny Evans_1988_NIR - Vereine: ['Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City']
#    ❌ Valon Berisha_1993_KVX - Vereine: ['Reims', 'Reims']
#    ❌ Nedim Bajrami_1999_ALB - Vereine: ['Empoli', 'Empoli']
#    ❌ Nï¿½lson Semedo_1993_POR - Vereine: ['Wolves', 'Wolves', 'Wolves', 'Wolves']
#    ❌ Danilo Pereira_1991_POR - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Arne Maier_1999_GER - Vereine: ['Augsburg', 'Augsburg']
#    ❌ Lucas Da Cunha_2001_FRA - Vereine: ['Clermont Foot', 'Nice']
#    ❌ James Maddison_1996_ENG - Vereine: ['Leicester City', 'Leicester City']
#    ❌ Isaac Hayden_1995_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd']
#    ❌ Mario Gaspar_1990_ESP - Vereine: ['Villarreal', 'Villarreal']
#    ❌ Tyler Roberts_1999_WAL - Vereine: ['Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Josip Brekalo_1998_CRO - Vereine: ['Torino', 'Torino']
#    ❌ Mï¿½rio Rui_1991_POR - Vereine: ['Napoli', 'Napoli']
#    ❌ Carney Chukwuemeka_2004_ENG - Vereine: ['Aston Villa', 'Aston Villa']
#    ❌ Jeremie Boga_1997_CIV - Vereine: ['Sassuolo', 'Atalanta']
#    ❌ Patrick Berg_1997_NOR - Vereine: ['Lens', 'Lens', 'Lens', 'Lens', 'Lens', 'Lens']
#    ❌ Demba Seck_2001_SEN - Vereine: ['Torino', 'Torino']
#    ❌ Domingos Duarte_1995_POR - Vereine: ['Granada', 'Granada']
#    ❌ Ashley Young_1985_ENG - Vereine: ['Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa', 'Aston Villa']
#    ❌ Dejan Kulusevski_2000_SWE - Vereine: ['Tottenham', 'Juventus']
#    ❌ Yannick Carrasco_1993_BEL - Vereine: ['Atlï¿½tico Madrid', 'Atlï¿½tico Madrid', 'Atlï¿½tico Madrid', 'Atlï¿½tico Madrid', 'Atlï¿½tico Madrid', 'Atlï¿½tico Madrid']
#    ❌ Nadiem Amiri_1996_GER - Vereine: ['Genoa', 'Leverkusen']
#    ❌ Jonas Martin_1990_FRA - Vereine: ['Rennes', 'Rennes', 'Rennes', 'Rennes', 'Rennes', 'Rennes', 'Rennes', 'Rennes']
#    ❌ Gabriel Veiga_2002_ESP - Vereine: ['Celta Vigo', 'Celta Vigo']
#    ❌ Pierre Kalulu_2000_FRA - Vereine: ['Milan', 'Milan']
#    ❌ Hiroki Ito_1999_JPN - Vereine: ['Stuttgart', 'Stuttgart', 'Stuttgart']
#    ❌ Anthony Martial_1995_FRA - Vereine: ['Sevilla', 'Sevilla', 'Manchester Utd', 'Manchester Utd']
#    ❌ Daniel Caligiuri_1988_ITA - Vereine: ['Augsburg', 'Augsburg']
#    ❌ Jacob Bruun Larsen_1998_DEN - Vereine: ['Hoffenheim', 'Hoffenheim', 'Hoffenheim']
#    ❌ Jens Stryger Larsen_1991_DEN - Vereine: ['Udinese', 'Udinese', 'Udinese']
#    ❌ Enock Mwepu_1998_ZAM - Vereine: ['Brighton', 'Brighton']
#    ❌ Oliver Baumann_1990_GER - Vereine: ['Hoffenheim', 'Hoffenheim']
#    ❌ Gonzalo Montiel_1997_ARG - Vereine: ['Sevilla', 'Sevilla', 'Sevilla', 'Sevilla', 'Sevilla', 'Sevilla', 'Sevilla']
#    ❌ Valentin Rongier_1994_FRA - Vereine: ['Marseille', 'Marseille']
#    ❌ Miguel_1999_ESP - Vereine: ['Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s']
#    ❌ Irvin Cardona_1997_FRA - Vereine: ['Brest', 'Brest', 'Brest', 'Brest', 'Brest']
#    ❌ Jonathan Schmid_1990_FRA - Vereine: ['Freiburg', 'Freiburg', 'Freiburg']
#    ❌ Waldemar Anton_1996_GER - Vereine: ['Stuttgart', 'Stuttgart']
#    ❌ Denis Zakaria_1996_SUI - Vereine: ['Juventus', "M'Gladbach"]
#    ❌ Marcus Coco_1996_FRA - Vereine: ['Nantes', 'Nantes']
#    ❌ Kevin Behrens_1991_GER - Vereine: ['Union Berlin', 'Union Berlin']
#    ❌ Patrick Herrmann_1991_GER - Vereine: ["M'Gladbach", "M'Gladbach", "M'Gladbach", "M'Gladbach"]
#    ❌ Dries Mertens_1987_BEL - Vereine: ['Napoli', 'Napoli']
#    ❌ Jordi Alba_1989_ESP - Vereine: ['Barcelona', 'Barcelona', 'Barcelona']
#    ❌ Akim Zedadka_1995_FRA - Vereine: ['Clermont Foot', 'Clermont Foot']
#    ❌ Pasquale Mazzocchi_1995_ITA - Vereine: ['Salernitana', 'Venezia']
#    ❌ Jean-Victor Makengo_1998_FRA - Vereine: ['Udinese', 'Udinese']
#    ❌ Ben White_1997_ENG - Vereine: ['Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal']
#    ❌ Giovanni Simeone_1995_ARG - Vereine: ['Hellas Verona', 'Hellas Verona']
#    ❌ Kevin-Prince Boateng_1987_GHA - Vereine: ['Hertha BSC', 'Hertha BSC']
#    ❌ Hï¿½vard Nielsen_1993_NOR - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Mohamed Ali Cho_2004_FRA - Vereine: ['Angers', 'Angers']
#    ❌ Boubacar Kamara_1999_FRA - Vereine: ['Marseille', 'Marseille']
#    ❌ Nils Petersen_1988_GER - Vereine: ['Freiburg', 'Freiburg']
#    ❌ Gary Medel_1987_CHI - Vereine: ['Bologna', 'Bologna']
#    ❌ Jonjo Shelvey_1992_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd']
#    ❌ Daniel James_1997_WAL - Vereine: ['Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Krepin Diatta_1999_SEN - Vereine: ['Monaco', 'Monaco']
#    ❌ Igor_1998_BRA - Vereine: ['Fiorentina', 'Fiorentina']
#    ❌ George Bello_2002_USA - Vereine: ['Arminia', 'Arminia', 'Arminia']
#    ❌ Matt Targett_1995_ENG - Vereine: ['Aston Villa', 'Newcastle Utd']
#    ❌ Leandro Paredes_1994_ARG - Vereine: ['Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G']
#    ❌ Demarai Gray_1996_ENG - Vereine: ['Everton', 'Everton', 'Everton']
#    ❌ Jarrod Bowen_1996_ENG - Vereine: ['West Ham', 'West Ham']
#    ❌ Timothy Tillman_1999_GER - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Mohamed Salah_1992_EGY - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Ciaran Clark_1989_IRL - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ Dani Ceballos_1996_ESP - Vereine: ['Real Madrid', 'Real Madrid']
#    ❌ Matt Ritchie_1989_SCO - Vereine: ['Newcastle Utd', 'Newcastle Utd']
#    ❌ Sven Michel_1990_GER - Vereine: ['Union Berlin', 'Union Berlin', 'Union Berlin']
#    ❌ Will Hughes_1995_ENG - Vereine: ['Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace']
#    ❌ Manuel Locatelli_1998_ITA - Vereine: ['Juventus', 'Juventus']
#    ❌ Youssouph Badji_2001_SEN - Vereine: ['Brest', 'Brest', 'Brest']
#    ❌ Darï¿½o Poveda_1997_ESP - Vereine: ['Getafe', 'Getafe']
#    ❌ Fernandinho_1985_BRA - Vereine: ['Manchester City', 'Manchester City']
#    ❌ Kristjan Asllani_2002_ALB - Vereine: ['Empoli', 'Empoli']
#    ❌ Matthieu Dreyer_1989_FRA - Vereine: ['Lorient', 'Lorient']
#    ❌ Lenny Joseph_2000_FRA - Vereine: ['Metz', 'Metz', 'Metz']
#    ❌ Niklas Stark_1995_GER - Vereine: ['Hertha BSC', 'Hertha BSC']
#    ❌ Romain Faivre_1998_FRA - Vereine: ['Brest', 'Lyon']
#    ❌ Dani Olmo_1998_ESP - Vereine: ['RB Leipzig', 'RB Leipzig']
#    ❌ Raï¿½l Moro_2002_ESP - Vereine: ['Lazio', 'Lazio', 'Lazio', 'Lazio']
#    ❌ Alberto Perea_1990_ESP - Vereine: ['Cï¿½diz', 'Cï¿½diz', 'Cï¿½diz', 'Cï¿½diz', 'Cï¿½diz', 'Cï¿½diz']
#    ❌ Mahdi Camara_1998_FRA - Vereine: ['Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne']
#    ❌ Tyrick Mitchell_1999_ENG - Vereine: ['Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace']
#    ❌ Andreas Christensen_1996_DEN - Vereine: ['Chelsea', 'Chelsea', 'Chelsea', 'Chelsea']
#    ❌ Wu Lei_1991_CHN - Vereine: ['Espanyol', 'Espanyol', 'Espanyol', 'Espanyol']
#    ❌ Ben Davies_1993_WAL - Vereine: ['Tottenham', 'Tottenham']
#    ❌ Ruan_1999_BRA - Vereine: ['Sassuolo', 'Sassuolo']
#    ❌ Paulinho_2000_BRA - Vereine: ['Leverkusen', 'Leverkusen', 'Leverkusen', 'Leverkusen', 'Leverkusen']
#    ❌ Josï¿½ Luis Morales_1987_ESP - Vereine: ['Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante', 'Levante']
#    ❌ Takefusa Kubo_2001_JPN - Vereine: ['Mallorca', 'Mallorca']
#    ❌ Kalvin Phillips_1995_ENG - Vereine: ['Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Moussa Diaby_1999_FRA - Vereine: ['Leverkusen', 'Leverkusen', 'Leverkusen', 'Leverkusen']
#    ❌ Mariano_1993_DOM - Vereine: ['Real Madrid', 'Real Madrid']
#    ❌ Emanuel Vignato_2000_ITA - Vereine: ['Bologna', 'Bologna']
#    ❌ Roberto Firmino_1991_BRA - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Jeremie Frimpong_2000_NED - Vereine: ['Leverkusen', 'Leverkusen', 'Leverkusen', 'Leverkusen', 'Leverkusen']
#    ❌ Michail Antonio_1990_JAM - Vereine: ['West Ham', 'West Ham']
#    ❌ Sheraldo Becker_1995_SUR - Vereine: ['Union Berlin', 'Union Berlin', 'Union Berlin', 'Union Berlin', 'Union Berlin', 'Union Berlin', 'Union Berlin', 'Union Berlin']
#    ❌ Robert Lewandowski_1988_POL - Vereine: ['Bayern Munich', 'Bayern Munich', 'Bayern Munich', 'Bayern Munich']
#    ❌ Brandon Williams_2000_ENG - Vereine: ['Norwich City', 'Norwich City']
#    ❌ Ruben Vargas_1998_SUI - Vereine: ['Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg', 'Augsburg']
#    ❌ Jay Rodriguez_1989_ENG - Vereine: ['Burnley', 'Burnley', 'Burnley']
#    ❌ Shane Duffy_1992_IRL - Vereine: ['Brighton', 'Brighton', 'Brighton', 'Brighton']
#    ❌ Oussama Idrissi_1996_MAR - Vereine: ['Sevilla', 'Cï¿½diz']
#    ❌ Kingsley Coman_1996_FRA - Vereine: ['Bayern Munich', 'Bayern Munich', 'Bayern Munich', 'Bayern Munich']
#    ❌ Maya Yoshida_1988_JPN - Vereine: ['Sampdoria', 'Sampdoria', 'Sampdoria', 'Sampdoria']
#    ❌ David Ospina_1988_COL - Vereine: ['Napoli', 'Napoli']
#    ❌ Tiemouï¿½ Bakayoko_1994_FRA - Vereine: ['Milan', 'Milan', 'Milan', 'Milan', 'Milan']
#    ❌ Dango Ouattara_2002_BFA - Vereine: ['Lorient', 'Lorient', 'Lorient', 'Lorient', 'Lorient']
#    ❌ ï¿½scar Gil_1997_ESP - Vereine: ['Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol', 'Espanyol']
#    ❌ Pablo Piatti_1989_ARG - Vereine: ['Elche', 'Elche']
#    ❌ Rï¿½ben Neves_1997_POR - Vereine: ['Wolves', 'Wolves', 'Wolves', 'Wolves']
#    ❌ Bakary Sako_1988_MLI - Vereine: ['Saint-ï¿½tienne', 'Saint-ï¿½tienne', 'Saint-ï¿½tienne']
#    ❌ William Carvalho_1992_POR - Vereine: ['Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis']
#    ❌ Conor Gallagher_2000_ENG - Vereine: ['Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace']
#    ❌ Ryan Sessegnon_2000_ENG - Vereine: ['Tottenham', 'Tottenham']
#    ❌ Lucas Moura_1992_BRA - Vereine: ['Tottenham', 'Tottenham', 'Tottenham']
#    ❌ Loum Ndiaye_1996_SEN - Vereine: ['Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s']
#    ❌ Renato Sanches_1997_POR - Vereine: ['Lille', 'Lille', 'Lille']
#    ❌ Pietro Pellegri_2001_ITA - Vereine: ['Torino', 'Milan']
#    ❌ Franco Russo_1994_ARG - Vereine: ['Mallorca', 'Mallorca', 'Mallorca', 'Mallorca']
#    ❌ Josï¿½ Luis Palomino_1990_ARG - Vereine: ['Atalanta', 'Atalanta', 'Atalanta', 'Atalanta']
#    ❌ Kieran Trippier_1990_ENG - Vereine: ['Newcastle Utd', 'Atlï¿½tico Madrid']
#    ❌ Edmond Tapsoba_1999_BFA - Vereine: ['Leverkusen', 'Leverkusen']
#    ❌ Dor Peretz_1995_ISR - Vereine: ['Venezia', 'Venezia']
#    ❌ Mads Pedersen_1996_DEN - Vereine: ['Augsburg', 'Augsburg', 'Augsburg', 'Augsburg']
#    ❌ Joachim Andersen_1996_DEN - Vereine: ['Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace', 'Crystal Palace']
#    ❌ Isaac Palazï¿½n Camacho_1994_ESP - Vereine: ['Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano']
#    ❌ Paul Bernardoni_1997_FRA - Vereine: ['Angers', 'Saint-ï¿½tienne']
#    ❌ Maximilian Eggestein_1996_GER - Vereine: ['Freiburg', 'Freiburg']
#    ❌ Bilal Brahimi_2000_FRA - Vereine: ['Angers', 'Angers', 'Nice', 'Nice']
#    ❌ Ronaldo Vieira_1998_GNB - Vereine: ['Sampdoria', 'Sampdoria', 'Sampdoria', 'Sampdoria']
#    ❌ Charlie Taylor_1993_ENG - Vereine: ['Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley']
#    ❌ Marco Reus_1989_GER - Vereine: ['Dortmund', 'Dortmund']
#    ❌ Chris Wood_1991_NZL - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Burnley', 'Burnley']
#    ❌ Pedro Neto_2000_POR - Vereine: ['Wolves', 'Wolves', 'Wolves', 'Wolves', 'Wolves']
#    ❌ Tachi_1997_ESP - Vereine: ['Alavï¿½s', 'Alavï¿½s']
#    ❌ Nikolas Nartey_2000_DEN - Vereine: ['Stuttgart', 'Stuttgart']
#    ❌ Batista Mendy_2000_FRA - Vereine: ['Angers', 'Angers', 'Angers', 'Angers']
#    ❌ Ferland Mendy_1995_FRA - Vereine: ['Real Madrid', 'Real Madrid']
#    ❌ Anthony Lopes_1990_POR - Vereine: ['Lyon', 'Lyon', 'Lyon', 'Lyon']
#    ❌ ï¿½lex Cantero_2000_ESP - Vereine: ['Levante', 'Levante']
#    ❌ Arthur_1998_BRA - Vereine: ['Fiorentina', 'Fiorentina', 'Fiorentina']
#    ❌ Pape Gueye_1999_SEN - Vereine: ['Marseille', 'Marseille']
#    ❌ Jean Lucas_1998_BRA - Vereine: ['Monaco', 'Monaco']
#    ❌ Jens Petter Hauge_1999_NOR - Vereine: ['Eint Frankfurt', 'Eint Frankfurt']
#    ❌ Ben Gibson_1993_ENG - Vereine: ['Norwich City', 'Norwich City']
#    ❌ Duvï¿½n Zapata_1991_COL - Vereine: ['Atalanta', 'Atalanta', 'Atalanta', 'Atalanta']
#    ❌ Diogo Jota_1996_POR - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Alex Sandro_1991_BRA - Vereine: ['Juventus', 'Juventus', 'Juventus']
#    ❌ Raheem Sterling_1994_ENG - Vereine: ['Manchester City', 'Manchester City']
#    ❌ Frank Onyeka_1998_NGA - Vereine: ['Brentford', 'Brentford']
#    ❌ Gio Reyna_2002_USA - Vereine: ['Dortmund', 'Dortmund', 'Dortmund']
#    ❌ Thilo Kehrer_1996_GER - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Emmanuel Dennis_1997_NGA - Vereine: ['Watford', 'Watford', 'Watford']
#    ❌ Rodrigo De Paul_1994_ARG - Vereine: ['Atlï¿½tico Madrid', 'Atlï¿½tico Madrid']
#    ❌ John Brooks_1993_USA - Vereine: ['Wolfsburg', 'Wolfsburg', 'Wolfsburg', 'Wolfsburg']
#    ❌ Jesï¿½s Corona_1993_MEX - Vereine: ['Sevilla', 'Sevilla']
#    ❌ Gonzalo Villar_1998_ESP - Vereine: ['Getafe', 'Getafe', 'Getafe', 'Getafe', 'Getafe', 'Getafe']
#    ❌ Toni Kroos_1990_GER - Vereine: ['Real Madrid', 'Real Madrid']
#    ❌ Sekou Mara_2002_FRA - Vereine: ['Bordeaux', 'Bordeaux', 'Bordeaux']
#    ❌ Eberechi Eze_1998_ENG - Vereine: ['Crystal Palace', 'Crystal Palace']
#    ❌ Fabien Lemoine_1987_FRA - Vereine: ['Lorient', 'Lorient']
#    ❌ Jordan Henderson_1990_ENG - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Yusuf Demir_2003_AUT - Vereine: ['Barcelona', 'Barcelona', 'Barcelona']
#    ❌ Cristian Gamboa_1989_CRC - Vereine: ['Bochum', 'Bochum']
#    ❌ Curtis Jones_2001_ENG - Vereine: ['Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool', 'Liverpool']
#    ❌ Jacob Murphy_1995_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ Cristian Tello_1991_ESP - Vereine: ['Betis', 'Betis', 'Betis']
#    ❌ Justin Kluivert_1999_NED - Vereine: ['Nice', 'Nice']
#    ❌ Marco Richter_1997_GER - Vereine: ['Hertha BSC', 'Hertha BSC', 'Hertha BSC']
#    ❌ Pierre-Emerick Aubameyang_1989_GAB - Vereine: ['Barcelona', 'Arsenal']
#    ❌ Chiquinho_2000_POR - Vereine: ['Wolves', 'Wolves', 'Wolves']
#    ❌ Dele Alli_1996_ENG - Vereine: ['Everton', 'Tottenham']
#    ❌ Deiver Machado_1993_COL - Vereine: ['Lens', 'Lens', 'Lens', 'Lens', 'Lens', 'Lens', 'Lens', 'Lens']
#    ❌ Luis Rioja_1993_ESP - Vereine: ['Alavï¿½s', 'Alavï¿½s']
#    ❌ Harvey Elliott_2003_ENG - Vereine: ['Liverpool', 'Liverpool', 'Liverpool']
#    ❌ Stefan Bell_1991_GER - Vereine: ['Mainz 05', 'Mainz 05', 'Mainz 05', 'Mainz 05', 'Mainz 05', 'Mainz 05']
#    ❌ Charles Traore_1992_MLI - Vereine: ['Nantes', 'Nantes', 'Nantes']
#    ❌ Marcos Alonso_1990_ESP - Vereine: ['Chelsea', 'Chelsea', 'Chelsea', 'Chelsea', 'Chelsea', 'Chelsea', 'Chelsea', 'Chelsea', 'Chelsea']
#    ❌ Christoph Baumgartner_1999_AUT - Vereine: ['Hoffenheim', 'Hoffenheim']
#    ❌ Adrien Silva_1989_POR - Vereine: ['Sampdoria', 'Sampdoria']
#    ❌ Andrï¿½ Silva_1995_POR - Vereine: ['RB Leipzig', 'RB Leipzig']
#    ❌ Caio Henrique Oliveira Silva_1997_BRA - Vereine: ['Monaco', 'Monaco']
#    ❌ Fï¿½bio Silva_2002_POR - Vereine: ['Wolves', 'Wolves']
#    ❌ Jonathan Silva_1994_ARG - Vereine: ['Getafe', 'Getafe', 'Getafe', 'Getafe']
#    ❌ Cï¿½dric Hountondji_1994_BEN - Vereine: ['Clermont Foot', 'Clermont Foot']
#    ❌ Nï¿½stor Araujo_1991_MEX - Vereine: ['Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo']
#    ❌ Andrea Carboni_2001_ITA - Vereine: ['Cagliari', 'Cagliari']
#    ❌ Andrï¿½ Hahn_1990_GER - Vereine: ['Augsburg', 'Augsburg']
#    ❌ Josï¿½ Mari_1987_ESP - Vereine: ['Cï¿½diz', 'Cï¿½diz']
#    ❌ Pathï¿½ Ciss_1994_SEN - Vereine: ['Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano', 'Rayo Vallecano']
#    ❌ Rayan Aï¿½t Nouri_2001_FRA - Vereine: ['Wolves', 'Wolves']
#    ❌ Renato Steffen_1991_SUI - Vereine: ['Wolfsburg', 'Wolfsburg']
#    ❌ Jacopo Sala_1991_ITA - Vereine: ['Spezia', 'Spezia', 'Spezia']
#    ❌ Matt Doherty_1992_IRL - Vereine: ['Tottenham', 'Tottenham', 'Tottenham']
#    ❌ Kiernan Dewsbury Hall_1998_ENG - Vereine: ['Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City', 'Leicester City']
#    ❌ Borna Sosa_1998_CRO - Vereine: ['Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart', 'Stuttgart']
#    ❌ Max Aarons_2000_ENG - Vereine: ['Norwich City', 'Norwich City']
#    ❌ Dani Alves_1983_BRA - Vereine: ['Barcelona', 'Barcelona', 'Barcelona', 'Barcelona', 'Barcelona', 'Barcelona', 'Barcelona']
#    ❌ Alberto Moreno_1992_ESP - Vereine: ['Villarreal', 'Villarreal']
#    ❌ Santiago Arzamendia_1998_PAR - Vereine: ['Cï¿½diz', 'Cï¿½diz', 'Cï¿½diz']
#    ❌ Bryan_2001_ESP - Vereine: ['Valencia', 'Valencia']
#    ❌ Aleix Vidal_1989_ESP - Vereine: ['Espanyol', 'Espanyol']
#    ❌ Arturo Vidal_1987_CHI - Vereine: ['Inter', 'Inter']
#    ❌ Yann Sommer_1988_SUI - Vereine: ["M'Gladbach", "M'Gladbach", "M'Gladbach"]
#    ❌ Karim Rekik_1994_NED - Vereine: ['Sevilla', 'Sevilla']
#    ❌ Teun Koopmeiners_1998_NED - Vereine: ['Atalanta', 'Atalanta']
#    ❌ Federico Valverde_1998_URU - Vereine: ['Real Madrid', 'Real Madrid', 'Real Madrid']
#    ❌ Callum Wilson_1992_ENG - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ Xavi Simons_2003_NED - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Alexis Mac Allister_1998_ARG - Vereine: ['Brighton', 'Brighton']
#    ❌ Mario Hermoso_1995_ESP - Vereine: ['Atlï¿½tico Madrid', 'Atlï¿½tico Madrid']
#    ❌ Lucas Digne_1993_FRA - Vereine: ['Aston Villa', 'Everton']
#    ❌ Facundo Medina_1999_ARG - Vereine: ['Lens', 'Lens']
#    ❌ Pontus Jansson_1991_SWE - Vereine: ['Brentford', 'Brentford', 'Brentford', 'Brentford']
#    ❌ Martï¿½n Montoya_1991_ESP - Vereine: ['Betis', 'Betis', 'Betis']
#    ❌ Bamba Dieng_2000_SEN - Vereine: ['Marseille', 'Marseille']
#    ❌ Ander Guevara_1997_ESP - Vereine: ['Real Sociedad', 'Real Sociedad']
#    ❌ Alfonso Pedraza_1996_ESP - Vereine: ['Villarreal', 'Villarreal']
#    ❌ Jamal Lewis_1998_NIR - Vereine: ['Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd', 'Newcastle Utd']
#    ❌ Renato Tapia_1995_PER - Vereine: ['Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo', 'Celta Vigo']
#    ❌ Juan Miranda_2000_ESP - Vereine: ['Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis', 'Betis']
#    ❌ Corentin Jean_1995_FRA - Vereine: ['Lens', 'Lens', 'Lens', 'Lens']
#    ❌ Lago Junior_1990_CIV - Vereine: ['Mallorca', 'Mallorca']
#    ❌ Tanguy Ndombele_1996_FRA - Vereine: ['Tottenham', 'Lyon']
#    ❌ Fabinho_1993_BRA - Vereine: ['Liverpool', 'Liverpool']
#    ❌ Josh Dasilva_1998_ENG - Vereine: ['Brentford', 'Brentford']
#    ❌ Luke Thomas_2001_ENG - Vereine: ['Leicester City', 'Leicester City']
#    ❌ Maximilian Bauer_2000_GER - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Jacob Ramsey_2001_ENG - Vereine: ['Aston Villa', 'Aston Villa', 'Aston Villa']
#    ❌ Robin Koch_1996_GER - Vereine: ['Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Joakim Nilsson_1994_SWE - Vereine: ['Arminia', 'Arminia', 'Arminia']
#    ❌ Marquinhos_1994_BRA - Vereine: ['Paris S-G', 'Paris S-G', 'Paris S-G', 'Paris S-G']
#    ❌ Liam Cooper_1991_SCO - Vereine: ['Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United', 'Leeds United']
#    ❌ Stefan Ortega_1992_GER - Vereine: ['Arminia', 'Arminia', 'Arminia', 'Arminia', 'Arminia', 'Arminia', 'Arminia', 'Arminia']
#    ❌ Max Christiansen_1996_GER - Vereine: ['Greuther Fï¿½rth', 'Greuther Fï¿½rth', 'Greuther Fï¿½rth']
#    ❌ Mitchel Bakker_2000_NED - Vereine: ['Leverkusen', 'Leverkusen']
#    ❌ Sebastian Andersson_1991_SWE - Vereine: ['Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln', 'Kï¿½ln']
#    ❌ Albin Ekdal_1989_SWE - Vereine: ['Sampdoria', 'Sampdoria']
#    ❌ Santiago Arias_1992_COL - Vereine: ['Granada', 'Granada', 'Granada', 'Granada', 'Granada', 'Granada', 'Granada']
#    ❌ Marvin Friedrich_1995_GER - Vereine: ['Union Berlin', "M'Gladbach"]
#    ❌ Antonio Puertas_1992_ESP - Vereine: ['Granada', 'Granada']
#    ❌ Harry Maguire_1993_ENG - Vereine: ['Manchester Utd', 'Manchester Utd', 'Manchester Utd', 'Manchester Utd', 'Manchester Utd']
#    ❌ Leon Bailey_1997_JAM - Vereine: ['Aston Villa', 'Aston Villa', 'Aston Villa']
#    ❌ Matteo Lovato_2000_ITA - Vereine: ['Atalanta', 'Cagliari']
#    ❌ Sergio Canales_1991_ESP - Vereine: ['Betis', 'Betis', 'Betis', 'Betis', 'Betis']
#    ❌ Nathan Collins_2001_IRL - Vereine: ['Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley', 'Burnley']
#    ❌ Rani Khedira_1994_GER - Vereine: ['Union Berlin', 'Union Berlin']
#    ❌ Nuno Tavares_2000_POR - Vereine: ['Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal', 'Arsenal']
#    ❌ Flavien Tait_1993_FRA - Vereine: ['Rennes', 'Rennes', 'Rennes']
#    ❌ Kevin Agudelo_1998_COL - Vereine: ['Spezia', 'Spezia']
#    ❌ Sinaly Diomande_2001_CIV - Vereine: ['Lyon', 'Lyon']
#    ❌ Gideon Mensah_1998_GHA - Vereine: ['Bordeaux', 'Bordeaux', 'Bordeaux', 'Bordeaux', 'Bordeaux', 'Bordeaux']
#    ❌ Ander Herrera_1989_ESP - Vereine: ['Paris S-G', 'Paris S-G']
#    ❌ Shandon Baptiste_1998_GRN - Vereine: ['Brentford', 'Brentford']
#    ❌ Gonzalo Escalante_1993_ARG - Vereine: ['Alavï¿½s', 'Alavï¿½s', 'Alavï¿½s']
#    ❌ Jorge de Frutos_1997_ESP - Vereine: ['Levante', 'Levante']
#    ❌ Rubï¿½n Alcaraz_1991_ESP - Vereine: ['Cï¿½diz', 'Cï¿½diz']
#    ❌ Rodrigo Bentancur_1997_URU - Vereine: ['Tottenham', 'Tottenham', 'Juventus', 'Juventus']
#    ❌ Ben Mee_1989_ENG - Vereine: ['Burnley', 'Burnley']
#    ❌ Luke Shaw_1995_ENG - Vereine: ['Manchester Utd', 'Manchester Utd']
#    ❌ Abdoulaye Bamba_1990_CIV - Vereine: ['Angers', 'Angers']
#    ❌ ï¿½scar de Marcos_1989_ESP - Vereine: ['Athletic Club', 'Athletic Club', 'Athletic Club']
#    ❌ Jonathan David_2000_CAN - Vereine: ['Lille', 'Lille', 'Lille', 'Lille', 'Lille']
#    ❌ Lukas Rupp_1991_GER - Vereine: ['Norwich City', 'Norwich City']
#    ❌ Diego Carlos_1993_BRA - Vereine: ['Sevilla', 'Sevilla', 'Sevilla', 'Sevilla', 'Sevilla']
#    ❌ Jorge Cuenca_1999_ESP - Vereine: ['Getafe', 'Getafe']
#    ❌ Cristiano Ronaldo_1985_POR - Vereine: ['Manchester Utd', 'Manchester Utd', 'Manchester Utd']
#    ❌ Vedat Muriqi_1994_KVX - Vereine: ['Lazio', 'Mallorca']
#    ❌ Nianzou Kouassi_2002_FRA - Vereine: ['Bayern Munich', 'Bayern Munich']
#    ❌ Mattias Svanberg_1999_SWE - Vereine: ['Bologna', 'Bologna']
#    ❌ Roberto Soriano_1991_ITA - Vereine: ['Bologna', 'Bologna']
#    ❌ Abdou Diallo_1996_SEN - Vereine: ['Paris S-G', 'Paris S-G', 'Paris S-G']
#    ❌ Ibrahima Diallo_1999_FRA - Vereine: ['Southampton', 'Southampton', 'Southampton']
#    ❌ Douglas Luiz_1998_BRA - Vereine: ['Aston Villa', 'Aston Villa']
#    ❌ Yussuf Poulsen_1994_DEN - Vereine: ['RB Leipzig', 'RB Leipzig', 'RB Leipzig']
#    ❌ Mattï¿½o Guendouzi_1999_FRA - Vereine: ['Marseille', 'Marseille']
# ✅ Transfer-Spieler entfernt!
#    Vorher: 2563 Zeilen
#    Nachher: 1078 Zeilen

# %%
player_stats_cleaned_separate = pd.read_csv('player_stats_cleaned_separate.csv')
player_stats_cleaned_separate
# Out:
#         Rk             Player Nation   Pos         Squad            Comp  \
# 0      923         Juan Foyth    ARG    DF    Villarreal         La Liga
# 1       97     Robert Andrich    GER    MF    Leverkusen      Bundesliga
# 2      426       Jens Cajuste    SWE    MF         Reims         Ligue 1
# 3     2297      Mads Roerslev    DEN    DF     Brentford  Premier League
# 4      530      Joris Chotard    FRA    MF   Montpellier         Ligue 1
# ...    ...                ...    ...   ...           ...             ...
# 1073  2280          Enzo Roco    CHI    DF         Elche         La Liga
# 1074  2605       Jonathan Tah    GER    DF    Leverkusen      Bundesliga
# 1075  2773    Edoardo Vergani    ITA  FWMF   Salernitana         Serie A
# 1076  2182        Teemu Pukki    FIN    FW  Norwich City  Premier League
# 1077  2575  Stefan Strandberg    NOR    DF   Salernitana         Serie A
#
#        Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon   OG  Recov  \
# 0     24.0  1998  25      22  ...  0.00  0.47  2.15   0.00   0.05  0.0   7.85
# 1     27.0  1994  26      21  ...  0.10  0.25  1.63   0.00   0.00  0.0  11.30
# 2     22.0  1999   8       4  ...  0.00  0.50  1.75   0.00   0.00  0.0   5.75
# 3     22.0  1999  21      12  ...  0.14  1.67  0.65   0.00   0.07  0.0   5.94
# 4     20.0  2001  36      33  ...  0.00  0.46  1.01   0.00   0.00  0.0   8.59
# ...    ...   ...  ..     ...  ...   ...   ...   ...    ...    ...  ...    ...
# 1073  29.0  1992  30      29  ...  0.04  0.00  0.81   0.00   0.07  0.0   8.13
# 1074  26.0  1996  33      33  ...  0.03  0.09  0.56   0.00   0.00  0.0   9.94
# 1075  21.0  2001   6       1  ...  0.91  0.00  0.91   0.00   0.00  0.0   5.45
# 1076  32.0  1990  37      37  ...  0.33  0.69  0.30   0.03   0.00  0.0   3.43
# 1077  31.0  1990  11      11  ...  0.10  0.58  0.77   0.00   0.10  0.1   9.13
#
#       AerWon  AerLost  AerWon%
# 0       2.24     1.03     68.6
# 1       2.08     1.09     65.6
# 2       0.50     1.50     25.0
# 3       1.16     2.17     34.8
# 4       0.77     0.89     46.3
# ...      ...      ...      ...
# 1073    2.82     1.27     69.0
# 1074    3.41     1.28     72.7
# 1075    1.82     2.73     40.0
# 1076    0.44     2.99     12.9
# 1077    3.46     1.06     76.6
#
# [1078 rows x 143 columns]

# %%
fifa_data_cleaned_separate = pd.read_csv('fifa_data_cleaned_separate.csv')
fifa_data_cleaned_separate
# Out:
#           ID             Name  Age  Nationality  Overall  Potential  \
# 0     165153       K. Benzema   34       France       91         91
# 1     158023         L. Messi   35    Argentina       91         91
# 2     192985     K. De Bruyne   31      Belgium       91         91
# 3     203376      V. van Dijk   30  Netherlands       90         90
# 4     167495         M. Neuer   36      Germany       90         90
# ...      ...              ...  ...          ...      ...        ...
# 1104  256873     21Â J. Paris   18      Germany       52         69
# 1105  262994    22Â B. McLean   18      England       52         60
# 1106  265630  22Â B. Williams   16      England       51         64
# 1107  262557        M. Caputo   16    Australia       50         70
# 1108  255856         S. Mandi   20        India       47         58
#
#                      Club      Value     Wage  Special Preferred Foot  \
# 0          Real Madrid CF     â¬64M  â¬450K     2147          Right
# 1     Paris Saint-Germain     â¬54M  â¬195K     2190           Left
# 2         Manchester City  â¬107.5M  â¬350K     2303          Right
# 3               Liverpool     â¬98M  â¬230K     2117          Right
# 4      FC Bayern MÃ¼nchen   â¬13.5M   â¬72K     1535          Right
# ...                   ...        ...      ...      ...            ...
# 1104     KFC Uerdingen 05    â¬180K   â¬500      824          Right
# 1105        Burton Albion    â¬160K   â¬500     1428          Right
# 1106       Harrogate Town    â¬130K   â¬500     1471          Right
# 1107    Melbourne City FC    â¬130K   â¬500     1324          Right
# 1108        Jamshedpur FC    â¬100K   â¬500     1226           Left
#
#       International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                          4.0        4.0          4.0  Medium/ Medium
# 1                          5.0        4.0          4.0        Low/ Low
# 2                          4.0        5.0          4.0      High/ High
# 3                          4.0        3.0          2.0    Medium/ High
# 4                          5.0        4.0          1.0  Medium/ Medium
# ...                        ...        ...          ...             ...
# 1104                       1.0        2.0          1.0  Medium/ Medium
# 1105                       1.0        2.0          2.0  Medium/ Medium
# 1106                       1.0        3.0          2.0  Medium/ Medium
# 1107                       1.0        3.0          2.0     Medium/ Low
# 1108                       1.0        3.0          2.0    Medium/ High
#
#              Body Type                     Position Height Weight
# 0     Normal (170-185)   <span class="pos pos21">CF  185cm   81kg
# 1               Unique   <span class="pos pos23">RW  169cm   67kg
# 2               Unique  <span class="pos pos13">RCM  181cm   70kg
# 3               Unique   <span class="pos pos6">LCB  193cm   92kg
# 4               Unique    <span class="pos pos0">GK  193cm   93kg
# ...                ...                          ...    ...    ...
# 1104     Normal (185+)  <span class="pos pos29">RES  188cm   83kg
# 1105       Lean (170-)  <span class="pos pos29">RES  168cm   65kg
# 1106    Lean (170-185)  <span class="pos pos28">SUB  180cm   70kg
# 1107    Lean (170-185)  <span class="pos pos28">SUB  182cm   74kg
# 1108  Normal (170-185)  <span class="pos pos28">SUB  174cm   73kg
#
# [1109 rows x 19 columns]

# %%
player_stats = pd.read_csv('player_stats_cleaned_separate.csv')
fifa_data = pd.read_csv('fifa_data_cleaned_separate.csv')

def get_last_name(name):
    return str(name).split()[-1].lower() if pd.notna(name) else ""

player_stats['last_name_temp'] = player_stats['Player'].apply(get_last_name)
fifa_data['last_name_temp'] = fifa_data['Name'].apply(get_last_name)

def find_strict_matches():
    matches = []
    
    for stats_idx, stats_row in player_stats.iterrows():
        stats_name = stats_row['Player']
        stats_last_name = stats_row['last_name_temp']
        stats_first_initial = stats_name[0].lower() if stats_name else ""
        
        possible_fifa_matches = fifa_data[fifa_data['last_name_temp'] == stats_last_name]
        
        for fifa_idx, fifa_row in possible_fifa_matches.iterrows():
            fifa_name = fifa_row['Name']
            fifa_first_initial = fifa_name[0].lower() if fifa_name else ""
            
            if (stats_first_initial == fifa_first_initial or 
                len(possible_fifa_matches) == 1):
                
                matches.append({
                    'stats_name': stats_name,
                    'fifa_name': fifa_name,
                    'last_name': stats_last_name,
                    'stats_index': stats_idx,
                    'fifa_index': fifa_idx,
                    'confidence': 'high' if stats_first_initial == fifa_first_initial else 'unique_lastname'
                })
                break  
    
    return matches

strict_matches = find_strict_matches()

if len(strict_matches) > 0:
    stats_indices = [match['stats_index'] for match in strict_matches]
    fifa_indices = [match['fifa_index'] for match in strict_matches]
    
    duplicate_stats = len(stats_indices) != len(set(stats_indices))
    duplicate_fifa = len(fifa_indices) != len(set(fifa_indices))
    
    if duplicate_stats or duplicate_fifa:
        seen_stats = set()
        seen_fifa = set()
        unique_matches = []
        
        for match in strict_matches:
            if (match['stats_index'] not in seen_stats and 
                match['fifa_index'] not in seen_fifa):
                
                seen_stats.add(match['stats_index'])
                seen_fifa.add(match['fifa_index'])
                unique_matches.append(match)
        
        strict_matches = unique_matches
    
    stats_indices = [match['stats_index'] for match in strict_matches]
    fifa_indices = [match['fifa_index'] for match in strict_matches]
    
    final_player_stats = player_stats.loc[stats_indices].drop('last_name_temp', axis=1)
    final_fifa_data = fifa_data.loc[fifa_indices].drop('last_name_temp', axis=1)
    
    if len(final_player_stats) != len(final_fifa_data):
        stats_players = set(final_player_stats['Player'])
        fifa_last_names = set(final_fifa_data['Name'].apply(get_last_name))
        
        problem_players = []
        for player in stats_players:
            if get_last_name(player) not in fifa_last_names:
                problem_players.append(player)
    
    validation_data = []
    for match in strict_matches:
        stats_player = final_player_stats[final_player_stats['Player'] == match['stats_name']].iloc[0]
        fifa_player = final_fifa_data[final_fifa_data['Name'] == match['fifa_name']].iloc[0]
        
        validation_data.append({
            'Stats_Player': match['stats_name'],
            'FIFA_Player': match['fifa_name'], 
            'Last_Name': match['last_name'],
            'Stats_Squad': stats_player['Squad'] if 'Squad' in stats_player else 'N/A',
            'FIFA_Club': fifa_player['Club'] if 'Club' in fifa_player else 'N/A',
            'FIFA_Overall': fifa_player['Overall'],
            'Confidence': match['confidence'],
            'VALIDIERT': '✅' 
        })
    
    validation_df = pd.DataFrame(validation_data)
    
    final_player_stats.to_csv('strict_player_stats.csv', index=False)

    final_fifa_data.to_csv('strict_fifa_data.csv', index=False)

    validation_df.to_csv('strict_validation.csv', index=False)

    stats_last_names = set(final_player_stats['Player'].apply(get_last_name))
    fifa_last_names = set(final_fifa_data['Name'].apply(get_last_name))
    
    missing_in_fifa = stats_last_names - fifa_last_names
    missing_in_stats = fifa_last_names - stats_last_names

player_stats = player_stats.drop('last_name_temp', axis=1)
fifa_data = fifa_data.drop('last_name_temp', axis=1)
